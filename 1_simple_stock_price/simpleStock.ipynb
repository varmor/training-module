# %%
pip install yfinance

# %%
import yfinance as yf

tickerSymbol = "GOOG"

# below method allows us to get market data and meta of the particular company
tickerData = yf.Ticker(tickerSymbol)

# %%
tickerData
# Out:
# yfinance.Ticker object <GOOG>

# %%
# the below dict get us the stock information
tickerData.info
# Out:
# <class 'dict'>
# {'address1': '1600 Amphitheatre Parkway',
#  'city': 'Mountain View',
#  'state': 'CA',
#  'zip': '94043',
#  'country': 'United States',
#  'phone': '650 253 0000',
#  'website': 'https://www.abc.xyz',
#  'industry': 'Internet Content & Information',
#  'industryDisp': 'Internet Content & Information',
#  'sector': 'Communication Services',
#  'sectorDisp': 'Communication Services',
# ...

# %%
tickerDF = tickerData.history(period='1d', start='2010-5-31', end='2020-5-31')

# %%
tickerDF
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2010-06-01 00:00:00-04:00  11.965899  12.230656  11.958178  12.014218
# 2010-06-02 00:00:00-04:00  12.121565  12.300644  11.991553  12.288191
# 2010-06-03 00:00:00-04:00  12.331528  12.652575  12.321317  12.592799
# 2010-06-04 00:00:00-04:00  12.446348  12.683708  12.371130  12.421441
# 2010-06-07 00:00:00-04:00  12.429910  12.475987  12.033645  12.092674
# ...                              ...        ...        ...        ...
# 2020-05-22 00:00:00-04:00  69.835503  70.638000  69.591499  70.521004
# 2020-05-26 00:00:00-04:00  71.863503  72.050003  70.606499  70.850998
# 2020-05-27 00:00:00-04:00  70.862503  71.086998  69.564499  70.891998
# 2020-05-28 00:00:00-04:00  69.843002  72.042000  69.800003  70.836502
# 2020-05-29 00:00:00-04:00  70.847000  71.628502  70.667503  71.445999
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tickerData.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-27 00:00:00-04:00        0.0      2.002000
# 2015-04-27 00:00:00-04:00        0.0      1.002746
# 2022-07-18 00:00:00-04:00        0.0     20.000000

# %%
print(tickerData.dividends)
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
print(type(tickerData.splits))
tickerData.splits
# Out:
# <class 'pandas.core.series.Series'>
# Date
# 2014-03-27 00:00:00-04:00     2.002000
# 2015-04-27 00:00:00-04:00     1.002746
# 2022-07-18 00:00:00-04:00    20.000000
# Name: Stock Splits, dtype: float64

# %%
type(tickerDF)
# Out:
# pandas.core.frame.DataFrame

# %%
data = yf.download("GOOG", start="2017-01-01", end="2023-08-30")
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   38.940498   39.481499   38.790001   39.306999   39.306999
# 2017-01-04   39.417999   39.567001   39.158001   39.345001   39.345001
# 2017-01-05   39.304001   39.723999   39.250999   39.701000   39.701000
# 2017-01-06   39.763000   40.395000   39.610199   40.307499   40.307499
# 2017-01-09   40.320000   40.498299   40.141499   40.332500   40.332500
# ...                ...         ...         ...         ...         ...
# 2023-08-23  130.850006  134.070007  130.509995  133.210007  133.210007
# 2023-08-24  134.727005  134.970001  130.300003  130.419998  130.419998
# 2023-08-25  130.139999  131.399994  128.039993  130.690002  130.690002
# 2023-08-28  132.080002  133.240005  130.850006  131.789993  131.789993
# 2023-08-29  132.998001  137.294998  132.979996  135.490005  135.490005
#
#               Volume
# Date
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame
