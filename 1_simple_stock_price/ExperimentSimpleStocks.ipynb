# %%
from datetime import date
from nsepy import get_history

# %%
sbin = get_history(symbol='SBIN',
                   start="2015,1,1",
                   end="2023,9,10")
# Out:
# Exception in thread Thread-15 (get_history):
# Traceback (most recent call last):
#   File "/Users/varmor/miniconda3/envs/dp/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/varmor/miniconda3/envs/dp/lib/python3.11/site-packages/nsepy/commons.py", line 132, in run
#     self.result = self._target(*self._args, **self._kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/varmor/miniconda3/envs/dp/lib/python3.11/site-packages/nsepy/history.py", line 138, in get_history
#     return get_history_quanta(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/varmor/miniconda3/envs/dp/lib/python3.11/site-packages/nsepy/history.py", line 143, in get_history_quanta
#     df = url_to_df(url=url,
#          ^^^^^^^^^^^^^^^^^^
#   File "/Users/varmor/miniconda3/envs/dp/lib/python3.11/site-packages/nsepy/history.py", line 151, in url_to_df
#     resp = url(**params)
#            ^^^^^^^^^^^^^
# ...
